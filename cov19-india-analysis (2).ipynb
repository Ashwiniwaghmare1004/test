# %% [markdown]
# <table>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>In [74]:</p>
# </blockquote></th>
# <th></th>
# <th></th>
# <th></th>
# <th></th>
# <th></th>
# <th></th>
# <th></th>
# <th></th>
# <th></th>
# <th></th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td>In [ ]:</td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# </tr>
# <tr class="even">
# <td>In [3]:</td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# </tr>
# <tr class="odd">
# <td>In [4]:</td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# </tr>
# <tr class="even">
# <td>Out[4]:</td>
# <td><strong>Sno</strong></td>
# <td><strong>Date</strong></td>
# <td><strong>Time</strong></td>
# <td><strong>State/UnionTerritory</strong></td>
# <td><strong>ConfirmedIndianNational</strong></td>
# <td><strong>ConfirmedForeignNational</strong></td>
# <td><strong>Cured</strong></td>
# <td><strong>Deaths</strong></td>
# <td><blockquote>
# <p><strong>Confirmed</strong></p>
# </blockquote></td>
# <td></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><strong>0</strong></td>
# <td>1</td>
# <td>2020-01-30</td>
# <td>6:00 PM</td>
# <td>Kerala</td>
# <td>1</td>
# <td>0</td>
# <td>0</td>
# <td>0</td>
# <td><blockquote>
# <p>1</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><strong>1</strong></td>
# <td>2</td>
# <td>2020-01-31</td>
# <td>6:00 PM</td>
# <td>Kerala</td>
# <td>1</td>
# <td>0</td>
# <td>0</td>
# <td>0</td>
# <td><blockquote>
# <p>1</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><strong>2</strong></td>
# <td>3</td>
# <td>2020-02-01</td>
# <td>6:00 PM</td>
# <td>Kerala</td>
# <td>2</td>
# <td>0</td>
# <td>0</td>
# <td>0</td>
# <td><blockquote>
# <p>2</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><strong>3</strong></td>
# <td>4</td>
# <td>2020-02-02</td>
# <td>6:00 PM</td>
# <td>Kerala</td>
# <td>3</td>
# <td>0</td>
# <td>0</td>
# <td>0</td>
# <td><blockquote>
# <p>3</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><strong>4</strong></td>
# <td>5</td>
# <td>2020-02-03</td>
# <td>6:00 PM</td>
# <td>Kerala</td>
# <td>3</td>
# <td>0</td>
# <td>0</td>
# <td>0</td>
# <td><blockquote>
# <p>3</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><strong>...</strong></td>
# <td>...</td>
# <td>...</td>
# <td>...</td>
# <td>...</td>
# <td>...</td>
# <td>...</td>
# <td>...</td>
# <td>...</td>
# <td><blockquote>
# <p>...</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><blockquote>
# <p><strong>16845</strong></p>
# </blockquote></td>
# <td><blockquote>
# <p>16846</p>
# </blockquote></td>
# <td>2021-07-07</td>
# <td>8:00 AM</td>
# <td>Telangana</td>
# <td>-</td>
# <td>-</td>
# <td><blockquote>
# <p>613124</p>
# </blockquote></td>
# <td>3703</td>
# <td><blockquote>
# <p>628282</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><blockquote>
# <p><strong>16846</strong></p>
# </blockquote></td>
# <td><blockquote>
# <p>16847</p>
# </blockquote></td>
# <td>2021-07-07</td>
# <td>8:00 AM</td>
# <td>Tripura</td>
# <td>-</td>
# <td>-</td>
# <td>63964</td>
# <td>701</td>
# <td><blockquote>
# <p>68612</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><blockquote>
# <p><strong>16847</strong></p>
# </blockquote></td>
# <td><blockquote>
# <p>16848</p>
# </blockquote></td>
# <td>2021-07-07</td>
# <td>8:00 AM</td>
# <td>Uttarakhand</td>
# <td>-</td>
# <td>-</td>
# <td><blockquote>
# <p>332006</p>
# </blockquote></td>
# <td>7338</td>
# <td><blockquote>
# <p>340882</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><blockquote>
# <p><strong>16848</strong></p>
# </blockquote></td>
# <td><blockquote>
# <p>16849</p>
# </blockquote></td>
# <td>2021-07-07</td>
# <td>8:00 AM</td>
# <td>Uttar Pradesh</td>
# <td>-</td>
# <td>-</td>
# <td>1682130</td>
# <td>22656</td>
# <td><blockquote>
# <p>1706818</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><blockquote>
# <p><strong>16849</strong></p>
# </blockquote></td>
# <td><blockquote>
# <p>16850</p>
# </blockquote></td>
# <td>2021-07-07</td>
# <td>8:00 AM</td>
# <td>West Bengal</td>
# <td>-</td>
# <td>-</td>
# <td>1472132</td>
# <td>17834</td>
# <td><blockquote>
# <p>1507241</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# <table>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p><strong>import</strong> numpy <strong>as</strong> np<br />
# <strong>import</strong> pandas <strong>as</strong> pd<br />
# <strong>import</strong> matplotlib.pyplot <strong>as</strong> plt<br />
# <strong>import</strong> plotly.express <strong>as</strong> px<br />
# <strong>import</strong> seaborn <strong>as</strong> sns</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# |     |
# |-----|
# |     |
#
# <table>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>data <strong>=</strong> pd<strong>.</strong>read_csv('covid_19_india.csv')</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# <table>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>data</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# > 16850 rows × 9 columns
# >
# > \# Cleansing
#
# <table>
# <thead>
# <tr class="header">
# <th>In [5]:</th>
# <th></th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td>In [6]:</td>
# <td></td>
# </tr>
# <tr class="even">
# <td>In [7]:</td>
# <td></td>
# </tr>
# <tr class="odd">
# <td>In [8]:</td>
# <td></td>
# </tr>
# <tr class="even">
# <td>In [9]:</td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><blockquote>
# <p>In [10]:</p>
# </blockquote></td>
# <td></td>
# </tr>
# <tr class="even">
# <td><blockquote>
# <p>In [204…</p>
# </blockquote></td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><blockquote>
# <p>In [207…</p>
# </blockquote></td>
# <td></td>
# </tr>
# <tr class="even">
# <td><blockquote>
# <p>In [208…</p>
# </blockquote></td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><blockquote>
# <p>In [209…</p>
# </blockquote></td>
# <td></td>
# </tr>
# <tr class="even">
# <td><blockquote>
# <p>Out[209…</p>
# </blockquote></td>
# <td><blockquote>
# <p>Kerala 525</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><blockquote>
# <p>Delhi 493</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><blockquote>
# <p>Rajasthan 492</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><blockquote>
# <p>Haryana 491</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><blockquote>
# <p>Uttar Pradesh 491</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><blockquote>
# <p>Ladakh 488</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><blockquote>
# <p>Tamil Nadu 488</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><blockquote>
# <p>Punjab 486</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><blockquote>
# <p>Jammu and Kashmir 486</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><blockquote>
# <p>Maharashtra 486</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><blockquote>
# <p>Karnataka 486</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><blockquote>
# <p>Andhra Pradesh 483</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><blockquote>
# <p>Uttarakhand 480</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><blockquote>
# <p>Odisha 479</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><blockquote>
# <p>Puducherry 477</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><blockquote>
# <p>West Bengal 477</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><blockquote>
# <p>Chhattisgarh 476</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><blockquote>
# <p>Chandigarh 476</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><blockquote>
# <p>Gujarat 475</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><blockquote>
# <p>Madhya Pradesh 474</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><blockquote>
# <p>Himachal Pradesh 474</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><blockquote>
# <p>Bihar 471</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><blockquote>
# <p>Manipur 471</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><blockquote>
# <p>Mizoram 470</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><blockquote>
# <p>Andaman and Nicobar Islands 469</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><blockquote>
# <p>Goa 469</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><blockquote>
# <p>Assam 463</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><blockquote>
# <p>Jharkhand 463</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><blockquote>
# <p>Arunachal Pradesh 461</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><blockquote>
# <p>Tripura 457</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><blockquote>
# <p>Meghalaya 450</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><blockquote>
# <p>Dadra and Nagar Haveli and Daman and Diu 426</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><blockquote>
# <p>Nagaland 417</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><blockquote>
# <p>Sikkim 410</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><blockquote>
# <p>Lakshadweep 209</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><blockquote>
# <p>Telangana 67</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><blockquote>
# <p>Dadra and Nagar Haveli 2</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><blockquote>
# <p>Bihar**** 2</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><blockquote>
# <p>Daman &amp; Diu 1</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><blockquote>
# <p>Name: State/UnionTerritory, dtype: int64</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# <table>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>data['Date']<strong>=</strong> pd<strong>.</strong>to_datetime(data['Date'])</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# <table>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>data['Year']<strong>=</strong> data['Date']<strong>.</strong>dt<strong>.</strong>year</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# <table>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>data['Month']<strong>=</strong> data['Date']<strong>.</strong>dt<strong>.</strong>month</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# <table>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>data['Day']<strong>=</strong> data['Date']<strong>.</strong>dt<strong>.</strong>day</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# <table>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>data <strong>=</strong> data[data['State/UnionTerritory']<strong>!=</strong>'Cases being reassigned to states']</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# <table>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>data <strong>=</strong> data[data['State/UnionTerritory']<strong>!=</strong>'Unassigned']</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# |     |
# |-----|
# |     |
#
# <table>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>data['ConfirmedIndianNational']<strong>.</strong>replace(to_replace<strong>=</strong>'-',value<strong>=</strong>'0',regex<strong>=True</strong>,inplace<strong>=True</strong>)</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# <table>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>data['ConfirmedForeignNational']<strong>.</strong>replace(to_replace<strong>=</strong>'-',value<strong>=</strong>'0',regex<strong>=True</strong>,inplace<strong>=True</strong>)</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# <table>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>data['State/UnionTerritory']<strong>.</strong>value_counts()</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# > \#\#\#\# Insights
#
# <table>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>In [236…</p>
# </blockquote></th>
# <th></th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>Out[236…</p>
# </blockquote></td>
# <td><blockquote>
# <p>State/UnionTerritory</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><blockquote>
# <p>Maharashtra 123531</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><blockquote>
# <p>Karnataka 35526</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><blockquote>
# <p>Tamil Nadu 33132</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><blockquote>
# <p>Delhi 25001</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><blockquote>
# <p>Uttar Pradesh 22656</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><blockquote>
# <p>West Bengal 17834</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><blockquote>
# <p>Punjab 16131</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><blockquote>
# <p>Kerala 13960</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><blockquote>
# <p>Chhattisgarh 13462</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><blockquote>
# <p>Andhra Pradesh 12898</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><blockquote>
# <p>Gujarat 10072</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><blockquote>
# <p>Bihar 9612</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><blockquote>
# <p>Haryana 9506</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><blockquote>
# <p>Bihar**** 9452</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><blockquote>
# <p>Madhya Pradesh 9017</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><blockquote>
# <p>Rajasthan 8942</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><blockquote>
# <p>Uttarakhand 7338</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><blockquote>
# <p>Jharkhand 5118</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><blockquote>
# <p>Assam 4717</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><blockquote>
# <p>Jammu and Kashmir 4345</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><blockquote>
# <p>Odisha 4299</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><blockquote>
# <p>Telangana 3703</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><blockquote>
# <p>Himachal Pradesh 3485</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><blockquote>
# <p>Goa 3079</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><blockquote>
# <p>Puducherry 1763</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><blockquote>
# <p>Manipur 1218</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <
p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><blockquote>
# <p>Andaman and Nicobar Islands 1589935</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><blockquote>
# <p>Mizoram 1534630</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><blockquote>
# <p>Dadra and Nagar Haveli and Daman and Diu 1470986</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><blockquote>
# <p>Bihar**** 1402468</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><blockquote>
# <p>Lakshadweep 471712</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><blockquote>
# <p>Dadra and Nagar Haveli 20352</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><blockquote>
# <p>Daman &amp; Diu 0</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><blockquote>
# <p>Name: Cured, dtype: int64</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td>In [ ]:</td>
# <td></td>
# </tr>
# <tr class="odd">
# <td>In [ ]:</td>
# <td></td>
# </tr>
# <tr class="even">
# <td><blockquote>
# <p>In [14]:</p>
# </blockquote></td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><blockquote>
# <p>Out[14]:</p>
# </blockquote></td>
# <td><blockquote>
# <p>Sno int64</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><blockquote>
# <p>Date datetime64[ns]</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><blockquote>
# <p>Time object</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><blockquote>
# <p>State/UnionTerritory object</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><blockquote>
# <p>ConfirmedIndianNational object</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><blockquote>
# <p>ConfirmedForeignNational object</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><blockquote>
# <p>Cured int64</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><blockquote>
# <p>Deaths int64</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><blockquote>
# <p>Confirmed int64</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><blockquote>
# <p>Year int64</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><blockquote>
# <p>Month int64</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><blockquote>
# <p>Day int64</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><blockquote>
# <p>dtype: object</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td>In [ ]:</td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><blockquote>
# <p>In [239…</p>
# </blockquote></td>
# <td></td>
# </tr>
# <tr class="even">
# <td><blockquote>
# <p>Out[239…</p>
# </blockquote></td>
# <td><blockquote>
# <p>State/UnionTerritory</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><blockquote>
# <p>Maharashtra 6113335</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><blockquote>
# <p>Kerala 2996094</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><blockquote>
# <p>Karnataka 2859595</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><blockquote>
# <p>Tamil Nadu 2503481</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><blockquote>
# <p>Andhra Pradesh 1908065</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><blockquote>
# <p>Uttar Pradesh 1706818</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><blockquote>
# <p>West Bengal 1507241</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><blockquote>
# <p>Delhi 1434687</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><blockquote>
# <p>Chhattisgarh 996359</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><blockquote>
# <p>Rajasthan 952836</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><blockquote>
# <p>Odisha 927186</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><blockquote>
# <p>Gujarat 823964</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><blockquote>
# <p>Madhya Pradesh 790042</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><blockquote>
# <p>Haryana 769030</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><blockquote>
# <p>Bihar 722746</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><blockquote>
# <p>Bihar**** 715730</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><blockquote>
# <p>Telangana 628282</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><blockquote>
# <p>Punjab 596736</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><blockquote>
# <p>Assam 522267</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><blockquote>
# <p>Jharkhand 346038</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><blockquote>
# <p>Uttarakhand 340882</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><blockquote>
# <p>Jammu and Kashmir 317481</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><blockquote>
# <p>Himachal Pradesh 202945</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><blockquote>
# <p>Goa 167823</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><blockquote>
# <p>Puducherry 118227</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><blockquote>
# <p>Manipur 73581</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><blockquote>
# <p>Tripura 68612</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><blockquote>
# <p>Chandigarh 61752</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><blockquote>
# <p>Meghalaya 52358</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><blockquote>
# <p>Arunachal Pradesh 37879</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><blockquote>
# <p>Nagaland 25619</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><blockquote>
# <p>Mizoram 22155</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><blockquote>
# <p>Sikkim 21403</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><blockquote>
# <p>Ladakh 20137</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><blockquote>
# <p>Dadra and Nagar Haveli and Daman and Diu 10575</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><blockquote>
# <p>Dadra and Nagar Haveli 10377</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><blockquote>
# <p>Lakshadweep 9947</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><blockquote>
# <p>Andaman and Nicobar Islands 7487</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><blockquote>
# <p>Daman &amp; Diu 2</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><blockquote>
# <p>Name: Confirmed, dtype: int64</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# <table>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>data<strong>.</strong>groupby('State/UnionTerritory')<strong>.</strong>Deaths<strong>.</strong>max()<strong>.</strong>sort_values(ascending<strong>=False</strong>)</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# <table>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>data<strong>.</strong>groupby('State/UnionTerritory')<strong>.</strong>Confirmed<strong>.</strong>mean()<strong>.</strong>sort_values(ascending<strong>=False</strong>)</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# <table>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>data<strong>.</strong>groupby('State/UnionTerritory')<strong>.</strong>Cured<strong>.</strong>sum()<strong>.</strong>sort_values(ascending<strong>=False</strong>)</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# |     |
# |-----|
# |     |
#
# |     |
# |-----|
# |     |
#
# <table>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>data<strong>.</strong>dtypes</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# |     |
# |-----|
# |     |
#
# <table>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>data<strong>.</strong>groupby('State/UnionTerritory')<strong>.</strong>Confirmed<strong>.</strong>max()<strong>.</strong>sort_values(ascending<strong>=False</strong>)</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# > \#\# Visualization
# >
# > india
#
# <table>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>In [233…</p>
# </blockquote></th>
# <th></th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>In [161…</p>
# </blockquote></td>
# <td></td>
# </tr>
# </tbody>
# </table>
#
# <table>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>cured_cases<strong>=</strong>px<strong>.</strong>scatter(data,y<strong>=</strong>'Cured',x<strong>=</strong>'Date',color<strong>=</strong>'Cured',title<strong>=</strong>'cured cases in India')<br />
# cured_cases<strong>.</strong>show()</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# <table>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>plt<strong>.</strong>figure(figsize<strong>=</strong>(10,9))<br />
# sg1 <strong>=</strong> sns<strong>.</strong>scatterplot(x<strong>=</strong>'Month',y<strong>=</strong>'Cured',hue<strong>=</strong>'Year',data<strong>=</strong>data,palette<strong>=</strong>'brg')<br />
# plt<strong>.</strong>show(sg1)</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# > <img src="attachment:vertopal_8d2cc51ec7fe4e409773ac66bad90ddc/media/image1.png" style="width:5.8625in;height:5.33472in" />
#
# <table>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>In [203…</p>
# </blockquote></th>
# <th></th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td>In [ ]:</td>
# <td></td>
# </tr>
# <tr class="even">
# <td><blockquote>
# <p>In [151…</p>
# </blockquote></td>
# <td></td>
# </tr>
# </tbody>
# </table>
#
# <table>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>px<strong>.</strong>pie(data,names<strong>=</strong>'State/UnionTerritory',values<strong>=</strong>'Deaths')</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# |     |
# |-----|
# |     |
#
# <table>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>plt<strong>.</strong>figure(figsize<strong>=</strong>(20,10))<br />
# sns<strong>.</strong>relplot(y<strong>=</strong>'Deaths',x<strong>=</strong>'Month',kind<strong>=</strong>'line',data<strong>=</strong>data)<br />
# plt<strong>.</strong>show()</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# > \<Figure size 1440x720 with 0 Axes\>
# >
# > <img src="attachment:vertopal_8d2cc51ec7fe4e409773ac66bad90ddc/media/image2.png" style="width:3.44444in;height:3.44444in" />
# >
# > plt.figure()
# > sns.histplot(data=data,y='State/UnionTerritory',color='blue')
# > plt.tight_layout() plt.show()
#
# <table>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>In [20]:</p>
# </blockquote></td>
# <td></td>
# </tr>
# </tbody>
# </table>
#
# <table>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>plt<strong>.</strong>figure(figsize<strong>=</strong>(20,10))<br />
# sns<strong>.</strong>histplot(data<strong>=</strong>data,y<strong>=</strong>'State/UnionTerritory',color<strong>=</strong>'blue')<br />
# plt<strong>.</strong>tight_layout()<br />
# plt<strong>.</strong>show()</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# > <img src="attachment:vertopal_8d2cc51ec7fe4e409773ac66bad90ddc/media/image3.png" style="width:13.81806in;height:6.88055in" />
#
# <table>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>In [108…</p>
# </blockquote></td>
# <td></td>
# </tr>
# </tbody>
# </table>
#
# <table>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>plt<strong>.</strong>figure(figsize<strong>=</strong>(20,10))<br />
# sns<strong>.</strong>scatterplot(x<strong>=</strong>'Cured',y<strong>=</strong>'State/UnionTerritory',hue<strong>=</strong>'Year',data<strong>=</strong>data,palette<strong>=</strong>'rainbow_r') plt<strong>.</strong>title('Cured_cases_year')<br />
# plt<strong>.</strong>show()</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# > <img src="attachment:vertopal_8d2cc51ec7fe4e409773ac66bad90ddc/media/image4.png" style="width:13.45694in;height:5.91111in" />
#
# <table>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>In [176…</p>
# </blockquote></th>
# <th></th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td>In [ ]:</td>
# <td></td>
# </tr>
# <tr class="even">
# <td><blockquote>
# <p>In [66]:</p>
# </blockquote></td>
# <td></td>
# </tr>
# </tbody>
# </table>
#
# <table>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>px<strong>.</strong>pie(data,names<strong>=</strong>'Year',values<strong>=</strong>'Cured')</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# |     |
# |-----|
# |     |
#
# <table>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>plt<strong>.</strong>figure(figsize<strong>=</strong>(10,9))<br />
# sns<strong>.</strong>catplot(x<strong>=</strong>'Year',y<strong>=</strong>'Cured',data<strong>=</strong>maharashtra)<em>#maharashtra</em><br />
# plt<strong>.</strong>show()</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# > \<Figure size 720x648 with 0 Axes\>
# >
# > <img src="attachment:vertopal_8d2cc51ec7fe4e409773ac66bad90ddc/media/image5.png" style="width:3.44444in;height:3.44583in" />
#
# <table>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>In [184…</p>
# </blockquote></td>
# <td></td>
# </tr>
# </tbody>
# </table>
#
# <table>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>plt<strong>.</strong>figure(figsize<strong>=</strong>(10,9))<br />
# sns<strong>.</strong>histplot(data<strong>=</strong>data,x<strong>=</strong>'Day',hue<strong>=</strong>'Year',palette<strong>=</strong>'Reds',multiple<strong>=</strong>'dodge',shrink<strong>=</strong>.9)<br />
# plt<strong>.</strong>show()</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# > <img src="attachment:vertopal_8d2cc51ec7fe4e409773ac66bad90ddc/media/image6.png" style="width:5.98889in;height:5.22639in" />
# >
# > px.bar(x='State/UnionTerritory',y='Deaths',data_frame=data)
#
# <table>
# <thead>
# <tr class="header">
# <th>In [ ]:</th>
# <th></th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>In [46]:</p>
# </blockquote></td>
# <td></td>
# </tr>
# <tr class="even">
# <td><blockquote>
# <p>In [119…</p>
# </blockquote></td>
# <td></td>
# </tr>
# <tr class="odd">
# <td><blockquote>
# <p>In [188…</p>
# </blockquote></td>
# <td></td>
# </tr>
# </tbody>
# </table>
#
# |     |
# |-----|
# |     |
#
# |     |
# |-----|
# |     |
#
# <table>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>cured_mean <strong>=</strong> data<strong>.</strong>groupby('State/UnionTerritory')<strong>.</strong>Cured<strong>.</strong>max()</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# <table>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>plt<strong>.</strong>figure(figsize<strong>=</strong>(10,9))<br />
# cured_mean<strong>.</strong>plot(kind<strong>=</strong>'bar',x<strong>=</strong>'State/UnionTerritory',y<strong>=</strong>'Cured')<br />
# plt<strong>.</strong>ylabel("Cured")<br />
# plt<strong>.</strong>show()</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# > <img src="attachment:vertopal_8d2cc51ec7fe4e409773ac66bad90ddc/media/image7.png" style="width:5.8625in;height:7.42778in" />
#
# <table>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>In [59]:</p>
# </blockquote></th>
# <th></th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>In [69]:</p>
# </blockquote></td>
# <td></td>
# </tr>
# </tbody>
# </table>
#
# <table>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>total_death <strong>=</strong> data<strong>.</strong>groupby('State/UnionTerritory')<strong>.</strong>Deaths<strong>.</strong>sum()</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# <table>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>plt<strong>.</strong>figure(figsize<strong>=</strong>(10,9))<br />
# total_death<strong>.</strong>plot(kind<strong>=</strong>'bar',x<strong>=</strong>'State/UnionTerritory',y<strong>=</strong>'Deaths')<br />
# plt<strong>.</strong>ylabel("Deaths")<br />
# <em>#total_death.ticklabel_format(useoffset=True)</em><br />
# plt<strong>.</strong>title("total_deaths")<br />
# plt<strong>.</strong>show()</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# > <img src="attachment:vertopal_8d2cc51ec7fe4e409773ac66bad90ddc/media/image8.png" style="width:6.01806in;height:7.47639in" />
#
# <table>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>In [75]:</p>
# </blockquote></th>
# <th></th>
# <th></th>
# <th></th>
# <th></th>
# <th></th>
# <th></th>
# <th></th>
# <th></th>
# <th></th>
# <th></th>
# <th></th>
# <th></th>
# <th></th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>Out[75]:</p>
# </blockquote></td>
# <td><strong>Sno</strong></td>
# <td><strong>Date</strong></td>
# <td><strong>Time</strong></td>
# <td><strong>State/UnionTerritory</strong></td>
# <td><strong>ConfirmedIndianNational</strong></td>
# <td><strong>ConfirmedForeignNational</strong></td>
# <td><strong>Cured</strong></td>
# <td><strong>Deaths</strong></td>
# <td><strong>Confirmed</strong></td>
# <td><strong>Year</strong></td>
# <td><strong>Month</strong></td>
# <td><blockquote>
# <p><strong>Day</strong></p>
# </blockquote></td>
# <td></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><strong>0</strong></td>
# <td>1</td>
# <td>2020-01-30</td>
# <td>6:00 PM</td>
# <td>Kerala</td>
# <td>1</td>
# <td>0</td>
# <td>0</td>
# <td>0</td>
# <td>1</td>
# <td>2020</td>
# <td>1</td>
# <td><blockquote>
# <p>30</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <
p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><blockquote>
# <p><strong>16849</strong></p>
# </blockquote></td>
# <td><blockquote>
# <p>16850</p>
# </blockquote></td>
# <td>2021-07-07</td>
# <td>8:00 AM</td>
# <td>West Bengal</td>
# <td>0</td>
# <td>0</td>
# <td>1472132</td>
# <td>17834</td>
# <td>1507241</td>
# <td>2021</td>
# <td>7</td>
# <td><blockquote>
# <p>7</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# <table>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>data</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# > 16787 rows × 12 columns
#
# <table>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>In [94]:</p>
# </blockquote></th>
# <th></th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>In [180…</p>
# </blockquote></td>
# <td></td>
# </tr>
# <tr class="even">
# <td><blockquote>
# <p>In [181…</p>
# </blockquote></td>
# <td></td>
# </tr>
# <tr class="odd">
# <td>In [ ]:</td>
# <td></td>
# </tr>
# <tr class="even">
# <td>In [ ]:</td>
# <td></td>
# </tr>
# </tbody>
# </table>
#
# <table>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>d2 <strong>=</strong> data<strong>.</strong>groupby('Year')<strong>.</strong>Confirmed<strong>.</strong>max()</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# <table>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>px<strong>.</strong>bar(data,x<strong>=</strong>'State/UnionTerritory',y<strong>=</strong>'Deaths')</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# <table>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>confirmed<strong>=</strong>px<strong>.</strong>bar(x<strong>=</strong>'Confirmed',y<strong>=</strong>'State/UnionTerritory',data_frame<strong>=</strong>data,color<strong>=</strong>'Year',title<strong>=</strong>'confirmed_cases') confirmed<strong>.</strong>show()</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# |     |
# |-----|
# |     |
#
# |     |
# |-----|
# |     |
#
# > MAHARASHTA
#
# <table>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>In [125…</p>
# </blockquote></th>
# <th></th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>In [128…</p>
# </blockquote></td>
# <td></td>
# </tr>
# </tbody>
# </table>
#
# <table>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>total_cured<strong>=</strong> data[data['State/UnionTerritory']<strong>==</strong>'Maharashtra']<strong>.</strong>groupby('Month')<strong>.</strong>Cured<strong>.</strong>sum()</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# <table>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>total_cured<strong>.</strong>plot<strong>.</strong>bar(figsize<strong>=</strong>(15,5))<br />
# plt<strong>.</strong>title('total_cured')<br />
# plt<strong>.</strong>show()</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# > <img src="attachment:vertopal_8d2cc51ec7fe4e409773ac66bad90ddc/media/image9.png" style="width:8.55278in;height:3.27778in" />
#
# <table>
# <thead>
# <tr class="header">
# <th>In [ ]:</th>
# <th></th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>In [131…</p>
# </blockquote></td>
# <td></td>
# </tr>
# </tbody>
# </table>
#
# <table>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>maharashtra <strong>=</strong> data[data['State/UnionTerritory']<strong>==</strong>'Maharashtra']</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# <table>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>plt<strong>.</strong>figure(figsize<strong>=</strong>(10,9))<br />
# month_cured <strong>=</strong> sns<strong>.</strong>scatterplot(x<strong>=</strong>'Month',y<strong>=</strong>'Cured',hue<strong>=</strong>'Year',data<strong>=</strong>maharashtra,palette<strong>=</strong>'brg') plt<strong>.</strong>show(month_cured)</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# > <img src="attachment:vertopal_8d2cc51ec7fe4e409773ac66bad90ddc/media/image10.png" style="width:5.8625in;height:5.33472in" />
#
# <table>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>In [152…</p>
# </blockquote></td>
# <td></td>
# </tr>
# </tbody>
# </table>
#
# <table>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>plt<strong>.</strong>figure(figsize<strong>=</strong>(20,10))<br />
# sns<strong>.</strong>relplot(y<strong>=</strong>'Deaths',x<strong>=</strong>'Month',kind<strong>=</strong>'line',data<strong>=</strong>maharashtra)<br />
# plt<strong>.</strong>show()</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# > \<Figure size 1440x720 with 0 Axes\>
# >
# > <img src="attachment:vertopal_8d2cc51ec7fe4e409773ac66bad90ddc/media/image11.png" style="width:3.44444in;height:3.44444in" />
#
# <table>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>In [214…</p>
# </blockquote></th>
# <th></th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>In [182…</p>
# </blockquote></td>
# <td></td>
# </tr>
# <tr class="even">
# <td><blockquote>
# <p>Out[182…</p>
# </blockquote></td>
# <td><blockquote>
# <p>&lt;seaborn.axisgrid.FacetGrid at 0x2340e9f6730&gt;</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# <table>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>px<strong>.</strong>pie(maharashtra,names<strong>=</strong>'Month',values<strong>=</strong>'Confirmed')</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# <table>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>sns<strong>.</strong>relplot(x<strong>=</strong>'Cured',y<strong>=</strong>'Day',data<strong>=</strong>maharashtra,hue<strong>=</strong>'Year',palette<strong>=</strong>'brg')<em># maharashtra</em></p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# > <img src="attachment:vertopal_8d2cc51ec7fe4e409773ac66bad90ddc/media/image12.png" style="width:4.03194in;height:3.44444in" />
#
# <table>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>In [232…</p>
# </blockquote></th>
# <th></th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>In [235…</p>
# </blockquote></td>
# <td></td>
# </tr>
# <tr class="even">
# <td><blockquote>
# <p>Out[235…</p>
# </blockquote></td>
# <td><blockquote>
# <p>State/UnionTerritory</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><blockquote>
# <p>Maharashtra 123531</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><blockquote>
# <p>Karnataka 35526</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><blockquote>
# <p>Tamil Nadu 33132</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><blockquote>
# <p>Delhi 25001</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><blockquote>
# <p>Uttar Pradesh 22656</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><blockquote>
# <p>West Bengal 17834</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><blockquote>
# <p>Punjab 16131</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><blockquote>
# <p>Kerala 13960</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><blockquote>
# <p>Chhattisgarh 13462</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><blockquote>
# <p>Andhra Pradesh 12898</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><blockquote>
# <p>Gujarat 10072</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><blockquote>
# <p>Bihar 9612</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><blockquote>
# <p>Haryana 9506</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><blockquote>
# <p>Bihar**** 9452</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><blockquote>
# <p>Madhya Pradesh 9017</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><blockquote>
# <p>Rajasthan 8942</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><blockquote>
# <p>Uttarakhand 7338</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><blockquote>
# <p>Jharkhand 5118</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><blockquote>
# <p>Assam 4717</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><blockquote>
# <p>Jammu and Kashmir 4345</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><blockquote>
# <p>Odisha 4299</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><blockquote>
# <p>Telangana 3703</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><blockquote>
# <p>Himachal Pradesh 3485</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><blockquote>
# <p>Goa 3079</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><blockquote>
# <p>Puducherry 1763</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><blockquote>
# <p>Manipur 1218</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><blockquote>
# <p>Meghalaya 880</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><blockquote>
# <p>Chandigarh 809</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><blockquote>
# <p>Tripura 701</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><blockquote>
# <p>Nagaland 503</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><blockquote>
# <p>Sikkim 309</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><blockquote>
# <p>Ladakh 204</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><blockquote>
# <p>Arunachal Pradesh 181</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><blockquote>
# <p>Andaman and Nicobar Islands 128</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><blockquote>
# <p>Mizoram 98</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><blockquote>
# <p>Lakshadweep 49</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><blockquote>
# <p>Dadra and Nagar Haveli and Daman and Diu 4</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><blockquote>
# <p>Dadra and Nagar Haveli 4</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td></td>
# <td><blockquote>
# <p>Daman &amp; Diu 0</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td></td>
# <td><blockquote>
# <p>Name: Deaths, dtype: int64</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td>In [ ]:</td>
# <td></td>
# </tr>
# </tbody>
# </table>
#
# <table>
# <tbody>
# <tr class="odd">
# <td><blockquote>
# <p>cured_cases<strong>=</strong>px<strong>.</strong>scatter(maharashtra,y<strong>=</strong>'Cured',x<strong>=</strong>'Date',color<strong>=</strong>'Cured',title<strong>=</strong>'cured cases in Maharashtra') cured_cases<strong>.</strong>show()</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# |     |
# |-----|
# |     |
#
# |     |
# |-----|
# |     |
